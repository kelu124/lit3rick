# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('acq/empty.txt', header=None)

# %%
data = np.array(df[0].to_list())
data
# Out:
# array([22247,  1878, 22017, ..., 26214,  7014,  9318])

# %%
plt.figure(figsize=(15,5))
plt.title("Empty run")
plt.plot(data)
plt.savefig("acq/empty.jpg")
